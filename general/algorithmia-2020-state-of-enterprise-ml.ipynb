# %% [markdown]
# # Algorithmia – 2020 State of Enterprise ML

# %% [markdown]
# Source: https://info.algorithmia.com/hubfs/2019/Whitepapers/The-State-of-Enterprise-ML-2020/Algorithmia_2020_State_of_Enterprise_ML.pdf.

# %%
import pandas as pd

# %%
# !mkdir data/
# Out:
# mkdir: cannot create directory ‘data/’: File exists

# %%
# %%writefile data/ml-use-case-frequency.csv
# Frequency,"Use case"
# 0.26,"Increase customer satisfaction"
# 0.14,"Filtering assets and content"
# 0.37,"Generating customer insights/intelligence"
# 0.26,"Reducing customer churn"
# 0.15,"Other"
# 0.25,"Predicting demand fluctuations"
# 0.38,"Reducing costs"
# 0.19,"Increase long-term customer engagement"
# 0.17,"Increase conversion rates"
# 0.27,"Recommender systems"
# 0.26,"Acquiring new customers"
# 0.29,"Retaining customers"
# 0.27,"Detecting fraud"
# 0.20,"Increase customer loyalty"
# 0.28,"Interacting with customers"
# 0.34,"Improving customer experience"
# 0.30,"Internal processing automation"
# Out:
# Overwriting data/ml-use-case-frequency.csv

# %%
df = pd.read_csv("data/ml-use-case-frequency.csv")

# %%
freq = df.set_index("Use case")["Frequency"].sort_values()
freq.plot.barh(title="Machine learniing use case frequency", xlabel="")
# Out:
# <AxesSubplot:title={'center':'Machine learniing use case frequency'}>
